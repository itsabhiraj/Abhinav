# %%
import pandas as pd
import numpy as np

# %%
df = pd.read_csv('titanic.csv')
df.head()
# Out:
#   Cabin            Ticket number  Survived
# 0   NaN         A/5 21171      5         0
# 1   C85          PC 17599      3         1
# 2   NaN  STON/O2. 3101282      6         1
# 3  C123            113803      3         1
# 4   NaN            373450      A         0

# %%
df['number'].unique()
# Out:
# array(['5', '3', '6', 'A', '2', '1', '4'], dtype=object)

# %%
fig = df['number'].value_counts().plot(kind='bar')
fig.set_title('Number of passengers')
# Out:
# Text(0.5, 1.0, 'Number of passengers')

# %%
# extracting numeric part
df['numbers numeric'] = pd.to_numeric(df['number'], errors='coerce', downcast='integer')

# %%
# extracting categorical part
df['numbers categorical'] = np.where(df['numbers numeric'].isnull(), df['number'], np.nan)
df.head()
# Out:
#   Cabin            Ticket number  Survived  numbers numeric  \
# 0   NaN         A/5 21171      5         0              5.0
# 1   C85          PC 17599      3         1              3.0
# 2   NaN  STON/O2. 3101282      6         1              6.0
# 3  C123            113803      3         1              3.0
# 4   NaN            373450      A         0              NaN
#
#   numbers categorical
# 0                 NaN
# 1                 NaN
# 2                 NaN
# 3                 NaN
# 4                   A

# %%
df['Cabin_num'] = df['Cabin'].str.extract('(\d+)') # captures numeric part
df['Cabin_str'] = df['Cabin'].str[0] # captures the first letter
df.head()
# Out:
#   Cabin            Ticket number  Survived  numbers numeric  \
# 0   NaN         A/5 21171      5         0              5.0
# 1   C85          PC 17599      3         1              3.0
# 2   NaN  STON/O2. 3101282      6         1              6.0
# 3  C123            113803      3         1              3.0
# 4   NaN            373450      A         0              NaN
#
#   numbers categorical Cabin_num Cabin_str
# 0                 NaN       NaN       NaN
# 1                 NaN        85         C
# 2                 NaN       NaN       NaN
# 3                 NaN       123         C
# 4                   A       NaN       NaN

# %%
df['Cabin_str'].value_counts().plot(kind='bar')
# Out:
# <Axes: xlabel='Cabin_str'>

# %%
# extract the last bit of ticket as number
df['ticket_num'] = df['Ticket'].apply(lambda s: s.split()[-1])
df['ticket_num'] = pd.to_numeric(df['ticket_num'],
                                   errors='coerce',
                                   downcast='integer')

# extract the first part of ticket as category
df['ticket_cat'] = df['Ticket'].apply(lambda s: s.split()[0])
df['ticket_cat'] = np.where(df['ticket_cat'].str.isdigit(), np.nan,
                              df['ticket_cat'])

df.head(20)
# Out:
#    Cabin            Ticket number  Survived  numbers numeric  \
# 0    NaN         A/5 21171      5         0              5.0
# 1    C85          PC 17599      3         1              3.0
# 2    NaN  STON/O2. 3101282      6         1              6.0
# 3   C123            113803      3         1              3.0
# 4    NaN            373450      A         0              NaN
# 5    NaN            330877      2         0              2.0
# 6    E46             17463      2         0              2.0
# 7    NaN            349909      5         0              5.0
# 8    NaN            347742      1         1              1.0
# 9    NaN            237736      A         1              NaN
# 10    G6           PP 9549      1         1              1.0
# 11  C103            113783      1         1              1.0
# 12   NaN         A/5. 2151      3         0              3.0
# 13   NaN            347082      3         0              3.0
# ...
